# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Lenovo\Documents\Ironhack\Project_Week_4\diamonds_clean.csv')
data = data.drop('Unnamed: 0', axis=1)
data = data.drop('Unnamed: 0.1', axis=1)

# %%
data.head()
# Out:
#    carat      cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    Ideal      5        2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium      5        8   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good      5        3   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium      1        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good      0        2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
data.describe().round(1)
# Out:
#          carat    color  clarity    depth    table    price        x        y  \
# count  53939.0  53939.0  53939.0  53939.0  53939.0  53939.0  53931.0  53932.0
# mean       0.8      3.4      4.8     61.7     57.5   3932.6      5.7      5.7
# std        0.5      1.7      2.2      1.4      2.2   3989.3      1.1      1.1
# min        0.2      0.0      1.0     43.0     43.0    326.0      3.7      3.7
# 25%        0.4      2.0      3.0     61.0     56.0    950.0      4.7      4.7
# 50%        0.7      3.0      4.0     61.8     57.0   2401.0      5.7      5.7
# 75%        1.0      5.0      7.0     62.5     59.0   5324.0      6.5      6.5
# max        5.0      6.0      8.0     79.0     95.0  18823.0     10.7     11.4
#
#              z
# count  53932.0
# mean       3.5
# std        0.7
# min        1.1
# 25%        2.9
# 50%        3.5
# 75%        4.0
# max        7.0

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %% [markdown]
# The mean are closed to the median,
# the preciosity, the carat minimum of carat os 0.2g and the maximum is 5g,
# the color are rank from best (7) to worst (1),
# the clarity also rank to from best (7) to worst (1),
# price go from 326 to 18823 with an average of 3932, 75% cost less than 5325
#
# Hypotheses: Price is growing with carat, carat is the more correled to the price

# %% [markdown]
#  1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
data.groupby(['color']).mean()
# Out:
#           carat   clarity      depth      table        price         x  \
# color
# 0      1.162137  4.654915  61.887215  57.812393  5323.818020  6.519338
# 1      1.026927  4.765031  61.846385  57.577278  5091.874954  6.222826
# 2      0.911668  4.845357  61.837203  57.517873  4485.739010  5.984522
# 3      0.771190  4.720687  61.757111  57.288629  3999.135671  5.678549
# 4      0.736538  4.770488  61.694582  57.433536  3724.886397  5.616727
# 5      0.657867  4.796468  61.662090  57.491201  3076.752475  5.411580
# 6      0.657795  4.935498  61.698125  57.404590  3169.954096  5.417851
#
#               y         z
# color
# 0      6.518105  4.033251
# 1      6.222730  3.846369
# 2      5.979882  3.698622
# 3      5.681198  3.507966
# 4      5.620634  3.465788
# 5      5.416949  3.337767
# 6      5.421928  3.343320

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
data_sorted=data.sort_values(by='color')
data_sorted
# Out:
#        carat        cut  color  clarity  depth  table  price     x     y     z
# 21993   1.66    Premium      0        6   62.6   59.0  10062  7.58  7.54  4.73
# 48247   0.70  Very Good      0        4   61.1   61.0   1952  5.64  5.69  3.46
# 48246   0.73  Very Good      0        4   60.6   61.0   1952  5.77  5.81  3.51
# 4899    1.01    Premium      0        4   61.0   61.0   3722  6.28  6.22  3.81
# 25166   2.15    Premium      0        8   62.4   60.0  13746  8.24  8.18  5.12
# ...      ...        ...    ...      ...    ...    ...    ...   ...   ...   ...
# 46511   0.63      Ideal      6        8   61.1   56.0   1779  5.52  5.58  3.39
# 24583   2.05    Premium      6        2   60.0   58.0  12891  8.31  8.23  4.96
# 24559   1.23      Ideal      6        6   62.0   55.0  12848  6.85  6.92  4.27
# 24602   1.75       Good      6        8   63.8   57.0  12918  7.63  7.53  4.84
# 53938   0.75      Ideal      6        2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53939 rows x 10 columns]

# %%
frequency=data['color'].value_counts()
frequency
# Out:
# 3    11292
# 5     9797
# 4     9542
# 2     8303
# 6     6775
# 1     5422
# 0     2808
# Name: color, dtype: int64

# %%
freq=pd.DataFrame(data['color'].value_counts())
freq.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
freq2=pd.DataFrame(data['cut'].value_counts())
freq2.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data['color'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
data.groupby(['carat'])['price', 'color', 'clarity', 'x', 'y', 'z'].mean().round(1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11624/3860044712.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['carat'])['price', 'color', 'clarity', 'x', 'y', 'z'].mean().round(1)
#          price  color  clarity     x     y    z
# carat
# 0.20     365.2    5.2      3.8   3.8   3.8  2.3
# 0.21     380.2    5.4      4.2   3.9   3.8  2.3
# 0.22     391.4    4.8      5.6   3.9   3.8  2.4
# 0.23     486.1    4.5      5.2   3.9   4.0  2.4
# 0.24     505.2    4.2      5.2   4.0   4.0  2.5
# ...        ...    ...      ...   ...   ...  ...
# 4.00   15984.0    1.0      1.0  10.0   9.9  6.3
# 4.01   15223.0    0.5      1.0  10.1  10.0  6.2
# 4.13   17329.0    2.0      1.0  10.0   9.8  6.4
# 4.50   18531.0    0.0      1.0  10.2  10.2  6.7
# 5.01   18018.0    0.0      1.0  10.7  10.5  7.0
#
# [273 rows x 6 columns]

# %% [markdown]
# clarity is incresing with carat
# price is increasing with carat
# color has not a linear distribution, can be low and expensive and cheap, seem also not relative to clarity
# I do a correlatio between color an price and color and clarity

# %%
data['price'].corr(data['color']) # negative correlation but low
# Out:
# -0.17248711469504305

# %%
data['clarity'].corr(data['color']) # no correlation
# Out:
# 0.018794807237079738

# %%
data['price'].corr(data['carat']) # hight correlation
# Out:
# 0.9215854690475589

# %%
data['price'].corr(data['clarity']) # little correlation
# Out:
# -0.07131147402732195

# %%
data['carat'].corr(data['clarity']) # little correlation
# Out:
# -0.13342602991229888

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
data['carat'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# small carat are very frequent, big carat are rare

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
data.groupby(['table'])['price', 'clarity','color', 'carat'].mean().round(1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11624/1386095532.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['table'])['price', 'clarity','color', 'carat'].mean().round(1)
#          price  clarity  color  carat
# table
# 43.0    4997.0      3.0    1.0    1.0
# 44.0     474.0      3.0    5.0    0.3
# 49.0    2290.5      5.5    3.0    0.6
# 50.0    8995.5      8.0    3.0    1.5
# 50.1    3353.0      2.0    2.0    0.9
# ...        ...      ...    ...    ...
# 71.0    1633.0      8.0    3.0    0.7
# 73.0    2406.5      3.8    4.5    0.6
# 76.0    2362.0      8.0    3.0    0.8
# 79.0    2301.0      2.0    4.0    0.8
# 95.0   13387.0      8.0    4.0    2.0
#
# [127 rows x 4 columns]

# %% [markdown]
# table/size of the diamonds seems not correled with price

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
data.groupby(['clarity'])['price', 'table','color', 'carat'].mean().round(1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11624/2055163484.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['clarity'])['price', 'table','color', 'carat'].mean().round(1)
#           price  table  color  carat
# clarity
# 1        3924.2   58.3    3.0    1.3
# 2        5062.3   57.9    3.5    1.1
# 3        3839.5   57.3    3.2    0.7
# 4        3925.0   57.4    3.5    0.8
# 5        2523.1   56.9    3.4    0.5
# 6        3283.7   57.0    3.6    0.6
# 7        2864.8   56.5    3.1    0.5
# 8        3996.0   57.7    3.4    0.9

# %% [markdown]
# clarity of the diamonds seems not correled with price

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
data.corr()
# Out:
#             carat     color   clarity     depth     table     price         x  \
# carat    1.000000 -0.291417 -0.133426  0.028321  0.181638  0.921585  0.977764
# color   -0.291417  1.000000  0.018795 -0.047312 -0.026469 -0.172487 -0.270760
# clarity -0.133426  0.018795  1.000000  0.005026 -0.038064 -0.071311 -0.128640
# depth    0.028321 -0.047312  0.005026  1.000000 -0.295797 -0.010572 -0.025021
# table    0.181638 -0.026469 -0.038064 -0.295797  1.000000  0.127147  0.196146
# price    0.921585 -0.172487 -0.071311 -0.010572  0.127147  1.000000  0.887217
# x        0.977764 -0.270760 -0.128640 -0.025021  0.196146  0.887217  1.000000
# y        0.976546 -0.270397 -0.126157 -0.028141  0.189821  0.888549  0.998364
# z        0.976325 -0.274986 -0.126823  0.096661  0.155915  0.882008  0.991005
#
#                 y         z
# carat    0.976546  0.976325
# color   -0.270397 -0.274986
# clarity -0.126157 -0.126823
# depth   -0.028141  0.096661
# table    0.189821  0.155915
# price    0.888549  0.882008
# x        0.998364  0.991005
# y        1.000000  0.990578
# z        0.990578  1.000000

# %%
#carat has the higher correlation with price

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(data, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
correlation more interesting: on the bottom left ( x,y,z /carat ) and top right ( carat/ x?y,y)
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11624/992767579.py", line 1
#     correlation more interesting: on the bottom left ( x,y,z /carat ) and top right ( carat/ x?y,y)
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(data.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %% [markdown]
# hight correlation with carat + price, x, y, z

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(data.carat, data.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(data.carat, data.price)
r2 = r_value ** 2
r2

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
